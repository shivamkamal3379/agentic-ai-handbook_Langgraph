# %%
# !pip install langchain-core langchain-community pydantic duckduckgo-search

# %%
# !pip install -U ddgs

# %%
pip install langchain-experimental

# %% [markdown]
# # Built in tool - DuckDuckGo Search

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun()

results = search_tool.invoke('What are the number of companies that are sufferieng from ai and removed the number of employees')

print(results)
# Out:
# 1 month ago - In fact, AI was responsible for almost 55,000 layoffs in the U.S. this year, according to consulting firm Challenger, Gray & Christmas. There were in total 1.17 million job cuts through 2025, the highest level since the Covid-19 pandemic in ... 5 days ago - AI Job Impact Forecast, AI will account for around 6% of job losses in the US between 2025 and 2030, equating to around 10.4 million roles. JP Gownder, Forrester VP principal analyst, said the scale of the upheaval will eclipse the number of ... 1 month ago - Expert estimates suggest the true automation-influenced displacement is likely above 150,000 . But the real cost isn’t on the severance line item; it is in the collapse of productivity among the survivors. December 11, 2025 - However, the job-cutting spree, ... “operational efficiency”. The tech giant announced a huge round of layoffs in May, with about 6,000 employees thought to have been affected.... 1 month ago - No. of Employees Impacted: ~14,000 Industry: Technology / E-commerce Date: October 2025 Amazon eliminated about 14,000 corporate jobs as it flattened management layers and pushed for faster decision-making. Beth Galetti, Amazon’s Senior Vice President pointed to advances in AI as one reason the company could operate more efficiently with fewer people, noting that automation was increasingly embedded across internal processes.

# %% [markdown]
# #Built-in Tool - Shell Tool

# %%
from langchain_community.tools import ShellTool

shell_tool = ShellTool()

results = shell_tool.invoke('Whoami')

print(results)
# Out:
# Executing command:
#  Whoami
# /bin/sh: 1: Whoami: not found
# /usr/local/lib/python3.12/dist-packages/langchain_community/tools/shell/tool.py:33: UserWarning: The shell tool has no safeguards by default. Use at your own risk.
#   warnings.warn(
