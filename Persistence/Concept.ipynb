# %% [markdown]
# Persistence in langgraph refers to the abiity to save and restore the state of a workflow over time .

# %% [markdown]
# fault tolerence is the biggest feature in langgraph

# %% [markdown]
# check pointer ->
#
#
# superstep -> checkpoint
#
# checkpoint -> state -> save
