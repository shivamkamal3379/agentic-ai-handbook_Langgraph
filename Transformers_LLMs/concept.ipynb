# %% [markdown]
# Sematic Extraction

# %% [markdown]
# NLP TASKS
#
# DATASETS-> twitter / IMDB critics / Amazon Reviews

# %% [markdown]
# Evaluation metrics

# %% [markdown]
# 1. Accuracy
# 2. percision
# 3. Recall
# 4. F1 Score
