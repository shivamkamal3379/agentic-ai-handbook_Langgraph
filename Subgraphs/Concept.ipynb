# %% [markdown]
# A subraph in langgraph  usually mean a graph that is embedded and executed as a node inside another graph

# %% [markdown]
# User -> LLM -> Output
#
#
#
#
# tools calls
#
# Rag
#
# conditional Routing
#
# Retries
#
# Memory
#
# HITL
#
# Evaluation
#
# Guardials

# %% [markdown]
# Uses of sub graph
# 1. modularity
# 2. resuability
# 3. maintainability

# %% [markdown]
# Langgraph uses of sub graphs
# 1. Failure isolation
# 2. State Separation
# 3. Observability

# %% [markdown]
# HOw sugraphs are used into a langgraph
