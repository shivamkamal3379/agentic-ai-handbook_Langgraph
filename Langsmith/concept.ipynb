# %% [markdown]
#  Concept of Observability

# %% [markdown]
# it is an ability to understand a system internal state by examining its external outputs , like logs , metrics and traces

# %% [markdown]
# it allows you to diagnose issues , understand performance and improve realibility by analyzing data generated by the system

# %% [markdown]
# essentially its about able to answer why something is happenig within a system  , even if you didnt anticipate the problem

# %% [markdown]
#  what is LangSmith ???

# %% [markdown]
# langsmith is a unified observability and evaluation platform where teams debug , test and monitor AI app performance

# %% [markdown]
# what does langsmith Trace ???
#
#
#
# input and output
# All the intermediate steps
# latency
# Token usage
# Cost
# Error
# Tags
# Cost
# Error
# Tags
# MetaData
